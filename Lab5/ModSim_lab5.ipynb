# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k=10
b=0.06
p=0.2
v=0.04
m=0.0975
w=0.0625
u=1/10
n0=10000000
q1=[0.0, 0.1, 0.2, 0.3, 0.4]

dt=1
T=np.arange(0,500+dt,dt)

for q in q1:
  s=[n0-100]
  sq=[0]
  e=[0]
  eq=[0]
  #iu,iq,id=[10],[0],[0]
  Iu,Iq,Id=[10],[0],[0]
  #r,d=[0],[0]
  R,D=[0],[0]
  n=[n0]
  for i in range(len(T)-1):
    #s.append(s[i]+(u*sq[i]-k*b*(1-q)*s[i]*iu[i]/n[i]-k*(1-b)*q*s[i]*iu[i]/n[i]-k*b*q*s[i]*iu[i]/n[i])*dt)
    # s.append(s[i]+(u*sq[i]-k*s[i]*iu[i]*(q+2*b*(1-q))/n[i])*dt)
    # sq.append(sq[i]+(k*(1-b)*q*s[i]*iu[i]/n[i]-u*sq[i])*dt)
    # e.append(e[i]+(k*b*(1-q)*s[i]*iu[i]/n[i]-p*e[i])*dt)
    # eq.append(eq[i]+(k*b*q*s[i]*iu[i]/n[i]-p*eq[i])*dt)
    # iu.append(iu[i]+(p*e[i]-(v+m+w)*iu[i])*dt)
    # iq.append(iq[i]+(p*eq[i]-(v+m+w)*iq[i])*dt)
    # id.append(id[i]+(w*(iu[i]+iq[i])-(v+m)*id[i])*dt)
    # d.append(d[i]+(m*(iq[i]+iu[i]+id[i]))*dt)
    # r.append(r[i]+(v*(iq[i]+iu[i]+id[i]))*dt)
    # n.append(n[i]+(-m*(iq[i]+iu[i]+id[i]))*dt)

    s.append(s[i]+(u*sq[i]-k*s[i]*Iu[i]*(q+2*b*(1-q))/n[i])*dt)
    sq.append(sq[i]+(-u*sq[i]+q*k*(1-b)*s[i]*Iu[i]/n[i])*dt)
    e.append(e[i]+(-p*e[i]+b*k*(1-q)*s[i]*Iu[i]/n[i])*dt)
    eq.append(eq[i]+(-p*eq[i]+b*k*q*s[i]*Iu[i]/n[i])*dt)
    Iu.append(Iu[i]+(p*e[i]-(m+v+w)*Iu[i])*dt)
    Iq.append(Iq[i]+(p*eq[i]-(m+v+w)*Iq[i])*dt)
    Id.append(Id[i]+(w*(Iu[i]+Iq[i])-(m+v)*Id[i])*dt)
    R.append(R[i]+(v*(Iq[i]+Id[i]+Iu[i]))*dt)
    D.append(D[i]+(m*(Iq[i]+Id[i]+Iu[i]))*dt)
    n.append(n[i]+(-m*(Iq[i]+Id[i]+Iu[i]))*dt)
  
  x=np.array(e)+np.array(eq)+np.array(Iu)+np.array(Id)+np.array(Iq)
  plt.plot(T,x/n0,label=f'q = {q}')

plt.legend()
plt.xlabel('Time (days)')
plt.ylabel('Fraction of the population infected')
plt.savefig('q_vary.png')
plt.title("Effect of varying 'q' ")
plt.grid(True)

# %%
k1=np.arange(5,25,5)
b=0.06
p=0.2
v=0.04
m=0.0975
w=0.0625
u=1/10
n0=10000000
q=0.2

dt=1
T=np.arange(0,700+dt,dt)

for k in k1:
  s=[n0-100]
  sq=[0]
  e=[0]
  eq=[0]
  #iu,iq,id=[10],[0],[0]
  Iu,Iq,Id=[10],[0],[0]
  #r,d=[0],[0]
  R,D=[0],[0]
  n=[n0]
  for i in range(len(T)-1):
    #s.append(s[i]+(u*sq[i]-k*b*(1-q)*s[i]*iu[i]/n[i]-k*(1-b)*q*s[i]*iu[i]/n[i]-k*b*q*s[i]*iu[i]/n[i])*dt)
    # s.append(s[i]+(u*sq[i]-k*s[i]*iu[i]*(q+2*b*(1-q))/n[i])*dt)
    # sq.append(sq[i]+(k*(1-b)*q*s[i]*iu[i]/n[i]-u*sq[i])*dt)
    # e.append(e[i]+(k*b*(1-q)*s[i]*iu[i]/n[i]-p*e[i])*dt)
    # eq.append(eq[i]+(k*b*q*s[i]*iu[i]/n[i]-p*eq[i])*dt)
    # iu.append(iu[i]+(p*e[i]-(v+m+w)*iu[i])*dt)
    # iq.append(iq[i]+(p*eq[i]-(v+m+w)*iq[i])*dt)
    # id.append(id[i]+(w*(iu[i]+iq[i])-(v+m)*id[i])*dt)
    # d.append(d[i]+(m*(iq[i]+iu[i]+id[i]))*dt)
    # r.append(r[i]+(v*(iq[i]+iu[i]+id[i]))*dt)
    # n.append(n[i]+(-m*(iq[i]+iu[i]+id[i]))*dt)

    s.append(s[i]+(u*sq[i]-k*s[i]*Iu[i]*(q+2*b*(1-q))/n[i])*dt)
    sq.append(sq[i]+(-u*sq[i]+q*k*(1-b)*s[i]*Iu[i]/n[i])*dt)
    e.append(e[i]+(-p*e[i]+b*k*(1-q)*s[i]*Iu[i]/n[i])*dt)
    eq.append(eq[i]+(-p*eq[i]+b*k*q*s[i]*Iu[i]/n[i])*dt)
    Iu.append(Iu[i]+(p*e[i]-(m+v+w)*Iu[i])*dt)
    Iq.append(Iq[i]+(p*eq[i]-(m+v+w)*Iq[i])*dt)
    Id.append(Id[i]+(w*(Iu[i]+Iq[i])-(m+v)*Id[i])*dt)
    R.append(R[i]+(v*(Iq[i]+Id[i]+Iu[i]))*dt)
    D.append(D[i]+(m*(Iq[i]+Id[i]+Iu[i]))*dt)
    n.append(n[i]+(-m*(Iq[i]+Id[i]+Iu[i]))*dt)
  
  x=np.array(e)+np.array(eq)+np.array(Iu)+np.array(Id)+np.array(Iq)
  plt.plot(T,x/n0,label=f'k = {k}')

plt.legend()
plt.xlabel('Time (days)')
plt.ylabel('Fraction of the population infected')
plt.savefig('k_vary.png')
plt.grid(True)
plt.title("Effect of varying 'k' ")
# Out:
# Text(0.5, 1.0, "Effect of varying 'k' ")

# %%
#k1=np.arange(5,25,5)
k=10
b=0.06
p=0.2
v=0.04
m=0.0975
#w=0.0625
u=1/10
n0=10000000
q=0.2

dt=1
T=np.arange(0,700+dt,dt)
days=np.arange(1,6,1)

for day in days:
  w=(1/day)-v-m
  s=[n0-100]
  sq=[0]
  e=[0]
  eq=[0]
  #iu,iq,id=[10],[0],[0]
  Iu,Iq,Id=[10],[0],[0]
  #r,d=[0],[0]
  R,D=[0],[0]
  n=[n0]
  for i in range(len(T)-1):
    #s.append(s[i]+(u*sq[i]-k*b*(1-q)*s[i]*iu[i]/n[i]-k*(1-b)*q*s[i]*iu[i]/n[i]-k*b*q*s[i]*iu[i]/n[i])*dt)
    # s.append(s[i]+(u*sq[i]-k*s[i]*iu[i]*(q+2*b*(1-q))/n[i])*dt)
    # sq.append(sq[i]+(k*(1-b)*q*s[i]*iu[i]/n[i]-u*sq[i])*dt)
    # e.append(e[i]+(k*b*(1-q)*s[i]*iu[i]/n[i]-p*e[i])*dt)
    # eq.append(eq[i]+(k*b*q*s[i]*iu[i]/n[i]-p*eq[i])*dt)
    # iu.append(iu[i]+(p*e[i]-(v+m+w)*iu[i])*dt)
    # iq.append(iq[i]+(p*eq[i]-(v+m+w)*iq[i])*dt)
    # id.append(id[i]+(w*(iu[i]+iq[i])-(v+m)*id[i])*dt)
    # d.append(d[i]+(m*(iq[i]+iu[i]+id[i]))*dt)
    # r.append(r[i]+(v*(iq[i]+iu[i]+id[i]))*dt)
    # n.append(n[i]+(-m*(iq[i]+iu[i]+id[i]))*dt)

    s.append(s[i]+(u*sq[i]-k*s[i]*Iu[i]*(q+2*b*(1-q))/n[i])*dt)
    sq.append(sq[i]+(-u*sq[i]+q*k*(1-b)*s[i]*Iu[i]/n[i])*dt)
    e.append(e[i]+(-p*e[i]+b*k*(1-q)*s[i]*Iu[i]/n[i])*dt)
    eq.append(eq[i]+(-p*eq[i]+b*k*q*s[i]*Iu[i]/n[i])*dt)
    Iu.append(Iu[i]+(p*e[i]-(m+v+w)*Iu[i])*dt)
    Iq.append(Iq[i]+(p*eq[i]-(m+v+w)*Iq[i])*dt)
    Id.append(Id[i]+(w*(Iu[i]+Iq[i])-(m+v)*Id[i])*dt)
    R.append(R[i]+(v*(Iq[i]+Id[i]+Iu[i]))*dt)
    D.append(D[i]+(m*(Iq[i]+Id[i]+Iu[i]))*dt)
    n.append(n[i]+(-m*(Iq[i]+Id[i]+Iu[i]))*dt)
  
  x=np.array(e)+np.array(eq)+np.array(Iu)+np.array(Id)+np.array(Iq)
  plt.plot(T,x/n0,label=f'1/(v + m + w) = {day}')

plt.legend()
plt.xlabel('Time (days)')
plt.ylabel('Fraction of the population infected')
plt.savefig('total_vary.png')
plt.grid(True)
plt.title('Effect of varying 1/(v+m+w)')
# Out:
# Text(0.5, 1.0, 'Effect of varying 1/(v+m+w)')

# %%
#k1=np.arange(5,25,5)
k=10
b=0.06
p=0.2
v=0.04
m=0.0975
w=0.0625
u=1/10
n0=10000000
#q=0.2

r_int=np.arange(0.5,3,0.5)
r=k*b/(v+m+w)

dt=1
T=np.arange(0,700+dt,dt)
q_values=np.arange(0,1.01,0.01)
#days=np.arange(1,6,1)

for i in r_int:
      d_value = np.zeros(100)
      count = 0
      for q in range(len(q_values)):
          d_value[q] = max(0,1 - i/(r*(1-q_values[q])))
          if d_value[q] == 0:
              count = q
              break
      plt.plot(q_values[0:count+1],d_value[0:count+1],label='r_int = '+str(i))
      #plt.annotate(f'r_int = {i}',xy=(count/2,count/2),xytext=(50,50))
      plt.legend()

plt.grid(b = True, color ='grey', linestyle ='-.', linewidth = 0.5, alpha = 0.6)
plt.xlabel('Proportion of contacts quarantined (q)')
plt.ylabel('1 - D_int/D')
plt.title('Proportional Reduction in Infectious period' )
plt.savefig('contour.png')

# %%
k=10
b=0.06
p=0.2
v=0.04
m=0.0975
#w=0.0625
u=1/10
n0=10000000
#q=0.2

dt=1
T=np.arange(0,500+dt,dt)
tq=np.arange(0,150,25)

s1=[]
i1=[]
r1=[]
d1=[]

for t1 in tq:
  s=[n0-100]
  sq=[0]
  e=[0]
  eq=[0]
  #iu,iq,id=[10],[0],[0]
  Iu,Iq,Id=[10],[0],[0]
  #r,d=[0],[0]
  R,D=[0],[0]
  n=[n0]
  q,w=0,0
  for i in range(len(T)-1):
    #s.append(s[i]+(u*sq[i]-k*b*(1-q)*s[i]*iu[i]/n[i]-k*(1-b)*q*s[i]*iu[i]/n[i]-k*b*q*s[i]*iu[i]/n[i])*dt)
    # s.append(s[i]+(u*sq[i]-k*s[i]*iu[i]*(q+2*b*(1-q))/n[i])*dt)
    # sq.append(sq[i]+(k*(1-b)*q*s[i]*iu[i]/n[i]-u*sq[i])*dt)
    # e.append(e[i]+(k*b*(1-q)*s[i]*iu[i]/n[i]-p*e[i])*dt)
    # eq.append(eq[i]+(k*b*q*s[i]*iu[i]/n[i]-p*eq[i])*dt)
    # iu.append(iu[i]+(p*e[i]-(v+m+w)*iu[i])*dt)
    # iq.append(iq[i]+(p*eq[i]-(v+m+w)*iq[i])*dt)
    # id.append(id[i]+(w*(iu[i]+iq[i])-(v+m)*id[i])*dt)
    # d.append(d[i]+(m*(iq[i]+iu[i]+id[i]))*dt)
    # r.append(r[i]+(v*(iq[i]+iu[i]+id[i]))*dt)
    # n.append(n[i]+(-m*(iq[i]+iu[i]+id[i]))*dt)

    s.append(s[i]+(u*sq[i]-k*s[i]*Iu[i]*(q+2*b*(1-q))/n[i])*dt)
    sq.append(sq[i]+(-u*sq[i]+q*k*(1-b)*s[i]*Iu[i]/n[i])*dt)
    e.append(e[i]+(-p*e[i]+b*k*(1-q)*s[i]*Iu[i]/n[i])*dt)
    eq.append(eq[i]+(-p*eq[i]+b*k*q*s[i]*Iu[i]/n[i])*dt)
    Iu.append(Iu[i]+(p*e[i]-(m+v+w)*Iu[i])*dt)
    Iq.append(Iq[i]+(p*eq[i]-(m+v+w)*Iq[i])*dt)
    Id.append(Id[i]+(w*(Iu[i]+Iq[i])-(m+v)*Id[i])*dt)
    R.append(R[i]+(v*(Iq[i]+Id[i]+Iu[i]))*dt)
    D.append(D[i]+(m*(Iq[i]+Id[i]+Iu[i]))*dt)
    n.append(n[i]+(-m*(Iq[i]+Id[i]+Iu[i]))*dt)

    if T[i]>=t1:
      q=0.2
      w=0.0625
  
  x=np.array(e)+np.array(eq)+np.array(Iu)+np.array(Id)+np.array(Iq)
  plt.plot(T,x/n0,label=f'$T_q$ = {t1}')
  s1.append(s[-1]+sq[-1])
  i1.append(np.max(np.array(e)+np.array(eq)+np.array(Iu)+np.array(Iq)+np.array(Id)))
  r1.append(R[-1])
  d1.append(D[-1])

plt.legend()
plt.xlabel('Time (days)')
plt.ylabel('Fraction of the population infected')
plt.savefig('time_vary.png')
plt.grid(True)
plt.title("Effect of delay in quarantine ")
# Out:
# Text(0.5, 1.0, 'Effect of delay in quarantine ')
